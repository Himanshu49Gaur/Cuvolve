# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Lab_Convolution')

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !nvidia-smi
# Out:
# Tue Apr 22 16:25:52 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !nvcc -arch=sm_75 -o convolution kernel.cu support.cu main.cu

# %%
# !./convolution
# Out:
# Setting up the problem...0.005416 s
# Allocating device variables...0.000152 s
# Copying data from host to device...0.001569 s
# Launching kernel...0.000259 s
# Copying data from device to host...0.000805 s
# Verification passed!
# Verifying results...TEST PASSED

# %%
# !./convolution 512
# Out:
# Setting up the problem...0.005376 s
# Allocating device variables...0.000125 s
# Copying data from host to device...0.000535 s
# Launching kernel...0.000261 s
# Copying data from device to host...0.000830 s
# Verification passed!
# Verifying results...TEST PASSED

# %%
# !./convolution 512 1024
# Out:
# Setting up the problem...0.007106 s
# Allocating device variables...0.000177 s
# Copying data from host to device...0.000549 s
# Launching kernel...0.000286 s
# Copying data from device to host...0.000934 s
# Verification passed!
# Verifying results...TEST PASSED
